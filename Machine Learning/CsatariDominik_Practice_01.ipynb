# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#data=pd.read_csv('../input/machine-learning/heart_disease.csv')
data=pd.read_csv('/content/heart_disease.csv')
label=data.values[:,0]
data=np.array(data.values[:,1:])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
np.size(label)
# Out:
# 302

# %% [markdown]
# # Új szakasz

# %%
class LinearRegression():
    def __init__(self):
        self.w_hat = None
        self.bias = None
    def fit(self,data,labels):
        #TODO
        
        
        self.w_hat =np.matmul(np.linalg.pinv(data), labels)
        self.bias = np.ones(labels.shape)

    def predict(self,data):
        return np.matmul(self.w_hat, data.T)+self.bias

    def mean_squared_error(self,true,prediction):
        return ((label - prediction)**2).mean()
    def mean_absolute_percentage_error(self,true,prediction):
        return np.mean(np.abs((label - prediction)/label))*100
        
    def mean_absolute_error(self,true,prediction):
        return np.mean(np.abs(label - prediction))

# %%
linreg=LinearRegression()
linreg.fit(data,label)
prediction=linreg.predict(data)
print(linreg.mean_squared_error(label,prediction))
print(linreg.mean_absolute_percentage_error(label,prediction))
print(linreg.mean_absolute_error(label,prediction))
# Out:
# 71.25701705534533
# 13.0310429199998
# 6.732730174295194
